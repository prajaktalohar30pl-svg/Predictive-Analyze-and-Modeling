# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-532d1179-a0d8-4238-b5ef-01ebca29a6a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-532d1179-a0d8-4238-b5ef-01ebca29a6a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import os
import ast
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
sns.set(style="whitegrid")
plt.rcParams['figure.figsize']=(10,5)

# %%
#step1:load tthe dataset
#check that your cvs files(tmdb_5000_movies.cvs and tmdb_5000_credit.cvs)
#Movie_Recommendation_Project/extract_files/
credits_path=os.path.join("/content/","tmdb_5000_credits.csv")
movies_path=os.path.join("/content/","tmdb_5000_movies.csv")

credits=pd.read_csv(credits_path)
movies=pd.read_csv(movies_path)

print("credit shape:",credits.shape)
print("movies shape:",movies.shape)
# Out:
# credit shape: (4803, 4)
# movies shape: (4803, 20)

# %%
#step 2: Merge movies and credits
movies=movies.merge(credits,on="title")
movies=movies[['movie_id','title','overview','genres','keywords','cast','crew']]
movies.dropna(inplace=True)
movies.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4128267122.py in <cell line: 0>()
#       1 #step 2: Merge movies and credits
# ----> 2 movies=movies.merge(credits,on="title")
#       3 movies=movies[['movie_id','title','overview','genres','keywords','cast','crew']]
#       4 movies.dropna(inplace=True)
#       5 movies.head(2)
#
# NameError: name 'movies' is not defined

# %%
import zipfile
import os

# Define the path to the uploaded zip file
zip_path = "/content/archive.zip"

# Define the directory where you want to extract the files
extract_dir = "/content/"

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all the contents into the specified directory
    zip_ref.extractall(extract_dir)

print(f"Files extracted to: {extract_dir}")
# Out:
# Files extracted to: /content/

# %%
#step1:load tthe dataset
#check that your cvs files(tmdb_5000_movies.cvs and tmdb_5000_credit.cvs)
#Movie_Recommendation_Project/extract_files/
credits_path=os.path.join("/content/","tmdb_5000_credits.csv")
movies_path=os.path.join("/content/","tmdb_5000_movies.csv")

credits=pd.read_csv(credits_path)
movies=pd.read_csv(movies_path)

print("credit shape:",credits.shape)
print("movies shape:",movies.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2684614511.py in <cell line: 0>()
#       5 movies_path=os.path.join("/content/","tmdb_5000_movies.csv")
#       6
# ----> 7 credits=pd.read_csv(credits_path)
#       8 movies=pd.read_csv(movies_path)
#       9
#
# NameError: name 'pd' is not defined

# %%
#step 2: Merge movies and credits
movies=movies.merge(credits,on="title")
movies=movies[['movie_id','title','overview','genres','keywords','cast','crew']]
movies.dropna(inplace=True)
movies.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4128267122.py in <cell line: 0>()
#       1 #step 2: Merge movies and credits
# ----> 2 movies=movies.merge(credits,on="title")
#       3 movies=movies[['movie_id','title','overview','genres','keywords','cast','crew']]
#       4 movies.dropna(inplace=True)
#       5 movies.head(2)
#
# NameError: name 'movies' is not defined

# %%
#step3: Convert JSOn-like column
def convert(text):
   return [i['name']for i in ast.literal_eval(text)]
movies['genres']=movies['genres'].apply(convert)
movies['keywords']=movies['keywords'].apply(convert)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2590833520.py in <cell line: 0>()
#       2 def convert(text):
#       3    return [i['name']for i in ast.literal_eval(text)]
# ----> 4 movies['genres']=movies['genres'].apply(convert)
#       5 movies['keywords']=movies['keywords'].apply(convert)
#
# NameError: name 'movies' is not defined

# %%
#Step 1: Load the Dataset
# Check that your CSV files (tmdb_5000_movies.csv and tmdb_5000_credits.csv) are in the folder:
#Movie_Recommendation_Project/extracted_files/

movies_path = os.path.join("/content/", "tmdb_5000_movies.csv")
credits_path = os.path.join("/content/", "tmdb_5000_credits.csv")

movies = pd.read_csv(movies_path)
credits = pd.read_csv(credits_path)

print("Movies shape:", movies.shape)
print("Credits shape:", credits.shape)
# Loading datasets and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-274925751.py in <cell line: 0>()
#       6 credits_path = os.path.join("/content/", "tmdb_5000_credits.csv")
#       7
# ----> 8 movies = pd.read_csv(movies_path)
#       9 credits = pd.read_csv(credits_path)
#      10
#
# ...

# %%
#Step 2: Merge Movies and Credits
movies = movies.merge(credits, on='title')
movies = movies[['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew']]
movies.dropna(inplace=True)
movies.head(2)
# Merging datasets and selecting relevant columns, ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3727660815.py in <cell line: 0>()
#       1 #Step 2: Merge Movies and Credits
# ----> 2 movies = movies.merge(credits, on='title')
#       3 movies = movies[['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew']]
#       4 movies.dropna(inplace=True)
#       5 movies.head(2)
#
# NameError: name 'movies' is not defined

# %%
#Step 3: Convert JSON-like Columns
def convert(text):
    return [i['name'] for i in ast.literal_eval(text)]

movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)
# Converting JSON-like columns and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-15693830.py in <cell line: 0>()
#       3     return [i['name'] for i in ast.literal_eval(text)]
#       4
# ----> 5 movies['genres'] = movies['genres'].apply(convert)
#       6 movies['keywords'] = movies['keywords'].apply(convert)
#       7 # Converting JSON-like columns. Correcting path issue.
#
# NameError: name 'movies' is not defined

# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import os
import ast
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10,5)
# Ensuring libraries are imported and dependencies are met.

# %%
#Extract top 3 cast members and director:
def convert_cast(text):
    L = []
    for i in ast.literal_eval(text):
        if len(L) < 3:
            L.append(i['name'])
    return L

def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
            break
    return L

movies['cast'] = movies['cast'].apply(convert_cast)
movies['crew'] = movies['crew'].apply(fetch_director)
# Extracting cast and director information and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4204291218.py in <cell line: 0>()
#      15     return L
#      16
# ---> 17 movies['cast'] = movies['cast'].apply(convert_cast)
#      18 movies['crew'] = movies['crew'].apply(fetch_director)
#      19 # Extracting cast and director information. Correcting path issue.
#
# NameError: name 'movies' is not defined

# %%
#Step 4: Create the tags Column
movies['overview'] = movies['overview'].apply(lambda x: x.split())
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']
new_df = movies[['movie_id', 'title', 'tags']]
new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x).lower())
# Creating tags column and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1018996347.py in <cell line: 0>()
#       1 #Step 4: Create the tags Column
# ----> 2 movies['overview'] = movies['overview'].apply(lambda x: x.split())
#       3 movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']
#       4 new_df = movies[['movie_id', 'title', 'tags']]
#       5 new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x).lower())
#
# NameError: name 'movies' is not defined

# %%
#Step 5: Exploratory Visualizations
#5.1 Top Genres
genre_list = []
for genres in movies['genres']:
    genre_list.extend(genres)

genre_counts = Counter(genre_list)
genre_df = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count']).sort_values(by='Count', ascending=False)

sns.barplot(x='Count', y='Genre', data=genre_df, palette='viridis')
plt.title("🎭 Top Movie Genres")
plt.show()
# Plotting Top Genres and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4146601384.py in <cell line: 0>()
#       2 #5.1 Top Genres
#       3 genre_list = []
# ----> 4 for genres in movies['genres']:
#       5     genre_list.extend(genres)
#       6
#
# NameError: name 'movies' is not defined

# %%
#5.2 Top Keywords
keyword_list = []
for kw in movies['keywords']:
    keyword_list.extend(kw)

keyword_counts = Counter(keyword_list)
keyword_df = pd.DataFrame(keyword_counts.items(), columns=['Keyword', 'Count']).sort_values(by='Count', ascending=False)[:15]

sns.barplot(x='Count', y='Keyword', data=keyword_df, palette='magma')
plt.title("💡 Top Keywords")
plt.show()
# Plotting Top Keywords and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2224144017.py in <cell line: 0>()
#       1 #5.2 Top Keywords
#       2 keyword_list = []
# ----> 3 for kw in movies['keywords']:
#       4     keyword_list.extend(kw)
#       5
#
# NameError: name 'movies' is not defined

# %%
#5.3 Top Actors
cast_list = []
for cast in movies['cast']:
    cast_list.extend(cast)

cast_counts = Counter(cast_list)
cast_df = pd.DataFrame(cast_counts.items(), columns=['Actor', 'Count']).sort_values(by='Count', ascending=False)[:15]

sns.barplot(x='Count', y='Actor', data=cast_df, palette='coolwarm')
plt.title("🎬 Most Frequent Actors")
plt.show()
# Plotting Most Frequent Actors and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3980196462.py in <cell line: 0>()
#       1 #5.3 Top Actors
#       2 cast_list = []
# ----> 3 for cast in movies['cast']:
#       4     cast_list.extend(cast)
#       5
#
# NameError: name 'movies' is not defined

# %%
#5.4 Top Directors
crew_list = []
for crew in movies['crew']:
    crew_list.extend(crew)

crew_counts = Counter(crew_list)
crew_df = pd.DataFrame(crew_counts.items(), columns=['Director', 'Count']).sort_values(by='Count', ascending=False)[:10]

sns.barplot(x='Count', y='Director', data=crew_df, palette='cubehelix')
plt.title("🎥 Most Frequent Directors")
plt.show()
# Plotting Most Frequent Directors and ensuring dependencies are met.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3541895865.py in <cell line: 0>()
#       1 #5.4 Top Directors
#       2 crew_list = []
# ----> 3 for crew in movies['crew']:
#       4     crew_list.extend(crew)
#       5
#
# NameError: name 'movies' is not defined

# %%
#Step 6: Feature Extraction & Cosine Similarity
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(new_df['tags'])
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

indices = pd.Series(new_df.index, index=new_df['title']).drop_duplicates()

# %%
#Step 7: Recommendation Function
def recommend(title, cosine_sim=cosine_sim):
    if title not in indices:
        print("Movie not found!")
        return
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:6]  # top 5
    movie_indices = [i[0] for i in sim_scores]
    print(f"Top Recommendations for: {title}")
    return new_df['title'].iloc[movie_indices]

# %%
#Step 8: Test the Recommender
recommend("Avatar")
# Out:
# Top Recommendations for: Avatar
# 2405             Aliens
# 838              Alien³
# 1533          Moonraker
# 373     Mission to Mars
# 3161              Alien
# Name: title, dtype: object

# %%
#product catalog(dictionary with product id as key)
products={
    1:{"name":"Laptop","Price":50000,"stock":5},
    2:{"name":"Phone","Price":20000,"stock":10},
    3:{"name":"Headph","Price":1500,"stock":15},
    4:{"name":"Charger","Price":700,"stock":20},
}

#empty cart dictionary
cart={}

#function to display available products
def show_products():
  print("\nAvailable Products:")
  print("ID\tName\tPrice\tStock")
  for pid,details in products.items():
    print(f"{pid}\t{details['name']}\t{details['Price']}\t{details['stock']}")

   # Function to add products to cart
def add_to_cart():
    show_products()
    try:
        pid = int(input("Enter Product ID to add: "))
        if pid not in products:
            print("Invalid Product ID!")
            return
        qty = int(input("Enter quantity: "))
        if qty > products[pid]["stock"]:
            print("Sorry, not enough stock!")
            return
        if pid in cart:
            cart[pid] += qty
        else:
            cart[pid] = qty
        products[pid]["stock"] -= qty
        print(f"{products[pid]['name']} added to cart.")
    except ValueError:
        print("Invalid input!")

# %%
 #Function to remove products from cart
def remove_from_cart():
    if not cart:
        print("Cart is empty!")
        return
    print("\nItems in Cart:")
    for pid, qty in cart.items():
        print(f"{pid} - {products[pid]['name']} : {qty}")
    try:
        pid = int(input("Enter Product ID to remove: "))
        if pid not in cart:
            print("Product not in cart!")
            return
        qty = int(input("Enter quantity to remove: "))
        if qty >= cart[pid]:
            products[pid]["stock"] += cart[pid]
            del cart[pid]
        else:
            cart[pid] -= qty
            products[pid]["stock"] += qty
        print("Item updated in cart.")
    except ValueError:
        print("Invalid input!")

# %%
# Function to view cart and total
def view_cart():
    if not cart:
        print("Cart is empty!")
        return
    total = 0
    print("\nYour Cart:")
    print("Name\tQuantity\tPrice")
    for pid, qty in cart.items():
        name = products[pid]["name"]
        price = products[pid]["Price"] * qty
        total += price
        print(f"{name}\t{qty}\t\t{price}")
    print(f"Total Amount: {total}")

# %%
# Function to checkout and save receipt
def checkout():
    if not cart:
        print("Cart is empty!")
        return
    total = 0
    print("\n--- Bill ---")
    with open("receipt.txt", "w") as f:
        f.write("----- Receipt -----\n")
        f.write("Name\tQuantity\tPrice\n")
        for pid, qty in cart.items():
            name = products[pid]["name"]
            price = products[pid]["Price"] * qty
            total += price
            f.write(f"{name}\t{qty}\t{price}\n")
        f.write(f"Total Amount: {total}\n")
        f.write("-------------------\n")
    print(f"Total Amount to pay: {total}")
    print("Receipt saved as 'receipt.txt'")
    cart.clear()  # Empty the cart after checkout

# %%
# Main menu loop
while True:
    print("\n--- Online Shopping Cart ---")
    print("1. Show Products")
    print("2. Add to Cart")
    print("3. Remove from Cart")
    print("4. View Cart")
    print("5. Checkout")
    print("6. Exit")

    try:
        choice = int(input("Enter your choice: "))
        if choice == 1:
            show_products()
        elif choice == 2:
            add_to_cart()
        elif choice == 3:
            remove_from_cart()
        elif choice == 4:
            view_cart()
        elif choice == 5:
            checkout()
        elif choice == 6:
            print("Thank you for shopping! Goodbye!")
            break
        else:
            print("Invalid choice!")
    except ValueError:
        print("Please enter a valid number!")
# Out:
# --- Online Shopping Cart ---
# 1. Show Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# Enter your choice: 1
#
# Available Products:
# ID	Name	Price	Stock
# 1	Laptop	50000	5
# 2	Phone	20000	6
# 3	Headph	1500	3
# 4	Charger	700	20
#
# --- Online Shopping Cart ---
# 1. Show Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# Enter your choice: 2
#
# Available Products:
# ID	Name	Price	Stock
# 1	Laptop	50000	5
# 2	Phone	20000	6
# 3	Headph	1500	3
# 4	Charger	700	20
# Enter Product ID to add: 3
# Enter quantity: 4
# Sorry, not enough stock!
#
# --- Online Shopping Cart ---
# 1. Show Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# Enter your choice: 5
#
# --- Bill ---
# Total Amount to pay: 98000
# Receipt saved as 'receipt.txt'
#
# --- Online Shopping Cart ---
# 1. Show Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# ...
